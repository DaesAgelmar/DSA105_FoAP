# %% [markdown]
# # DSA105 Final Project
# ## Three-Dimensional Analysis of Algorithmic Education
#
# ---
#
# **Student Name:** [Your Name Here]
#
# **Student ID:** [Your Student ID]
#
# **Date:** [Submission Date]
#
# ---
#
# ### Instructions
# - Complete all sections in this notebook
# - Use **Markdown cells** for written analysis and explanations
# - Use **Code cells** for Python implementations
# - Run all code cells before submission to ensure they execute without errors
# - Do not delete any section headers
# - Complete the AI Usage Log in Appendix A

# %% [markdown]
# ---
# ### 📚 Concept Guide
#
# Before you begin, familiarize yourself with these key terms:
#
# | Term | Definition | Türkçe |
# |------|------------|--------|
# | **Cognitive Load** | Mental effort required when learning multiple new concepts simultaneously | Bilişsel Yük — aynı anda çok fazla yeni bilgi öğrenmekten kaynaklanan zihinsel zorlanma |
# | **Spiral Learning** | Revisiting the same topic at increasing depth over time | Spiral Öğrenme — aynı konuyu zamanla daha derin işleme |
# | **Pythonic** | Code that follows Python's design philosophy: readable, concise, elegant | Python'a özgü, kısa ve şık çözümler |
# | **Pseudocode** | Algorithm description in plain language, no programming syntax | Programlama sözdizimi olmadan, düz dille algoritma anlatımı |
# | **Flowchart** | Visual diagram showing step-by-step process flow | Adım adım süreç akışını gösteren görsel diyagram |
#
# ---

# %% [markdown]
# ---
# # Section 1: From Pedagogical Critique to Practical Lesson Design (25 Points)
#
# *Bloom Levels: Remember, Understand, Create*

# %% [markdown]
# ## Task 1.1 - Anatomy of the Current Approach (10 Points)
#
# Analyze the following code example from a pedagogical perspective:

# %%
# CODE EXAMPLE TO ANALYZE (Do not modify this cell)
student_grades = [85, 42, 73, 95, 66, 88, 91, 54, 78, 82]
passed_grades = []

for grade in student_grades:
    if grade >= 70:
        passed_grades.append(grade)

print("Passed grades:", passed_grades)
print("Number of students who passed:", len(passed_grades))

# %% [markdown]
# ### Question 1.1a (2 points)
# Based on the DSA105 weekly schedule, in which week would this code example be taught? Justify your answer by referencing specific prerequisites from earlier weeks.
#
# **Your Answer:**
#
# [Write your answer here]

# %% [markdown]
# ### Question 1.1b (3 points)
# Does this example prioritize teaching *algorithmic thinking* or *Python syntax*? Explain with specific evidence from the code.
#
# **Your Answer:**
#
# [Write your answer here]

# %% [markdown]
# ### Question 1.1c (3 points)
# The code combines a `for` loop and `if` conditional simultaneously. What "cognitive load" risks does this create for first-time learners?
#
# **Your Answer:**
#
# [Write your answer here]

# %% [markdown]
# ### Question 1.1d (2 points)
# Create a **syntax-free** representation of this problem using either a flowchart (describe it textually or insert an image) or pseudocode.
#
# **Your Answer:**
#
# ```
# [Write your pseudocode or describe your flowchart here]
# ```

# %% [markdown]
# ## Task 1.2 - Alternative Pedagogical Approach Design (15 Points)
#
# Design a 3-stage lesson plan to teach the grade filtering concept:

# %% [markdown]
# ### Stage 1: Problem Understanding - Syntax-Free (5 points)
#
# **Plain Language Steps:**
#
# [Write the problem in plain English/Turkish steps]
#
# **Flowchart:**
#
# [Describe or draw your flowchart]
#
# **Pseudocode:**
#
# ```
# [Write your pseudocode here]
# ```

# %% [markdown]
# ### Stage 2: Building Blocks - Abstract Learning (5 points)
#
# Explain each concept **without code**, using real-world analogies:
#
# **Lists (Data Storage):**
#
# [Your explanation with analogy]
#
# **Conditional Logic ("If... Then"):**
#
# [Your explanation with analogy]
#
# **Iteration (Repetition):**
#
# [Your explanation with analogy]

# %% [markdown]
# ### Stage 3: Code Assembly (5 points)
#
# Show how each building block translates to Python, then combine them:

# %%
# Building Block 1: Creating a list
# [Your code here]

# Building Block 2: Conditional check (demonstrate with a single value)
# [Your code here]

# Building Block 3: Iteration (demonstrate simple loop)
# [Your code here]

# Combined Solution
# [Your code here]

# %% [markdown]
# ---
# # Section 2: Curriculum Architecture Analysis (20 Points)
#
# *Bloom Levels: Analyze, Evaluate*

# %% [markdown]
# > 💡 **Tip:** You're not expected to be a pedagogy expert. Write from your own experience as a learner. "This confused me because..." is a valid starting point.

# %% [markdown]
# ## Task 2.1 - Topic Sequencing Analysis (12 Points)
#
# The DSA105 curriculum follows this sequence:
#
# | Week | Topic |
# |------|-------|
# | 3 | Data types and variables |
# | 6 | Conditional statements and decision structures |
# | 8-9 | Loops and control flow / Nested loops |
# | 10 | Functions: definition, parameters, return values |
# | 11 | Lists and collections |

# %% [markdown]
# ### Question 2.1a (4 points)
# At which week can the "filter passing grades" problem be meaningfully solved? Identify any prerequisite gaps.
#
# **Your Answer:**
#
# [Write your answer here]

# %% [markdown]
# ### Question 2.1b (4 points)
# Which topics appear to be artificially separated that might benefit from integrated teaching?
#
# **Your Answer:**
#
# [Write your answer here]

# %% [markdown]
# ### Question 2.1c (4 points)
# Propose an alternative sequencing:
#
# `Variables → Lists → Loop Logic (abstract) → Conditional Logic (abstract) → Integrated Example → Python Translation → Functions`
#
# Justify why this might reduce cognitive load.
#
# **Your Answer:**
#
# [Write your answer here]

# %% [markdown]
# ## Task 2.2 - Cross-Disciplinary Connection Map (8 Points)

# %% [markdown]
# ### Statistics Connection (3 points)
# How does data filtering relate to subsample analysis and descriptive statistics (DSA101 concepts)?
#
# **Your Answer:**
#
# [Write your answer here]

# %% [markdown]
# ### Business Applications (3 points)
# Give two real-world examples where this filtering logic applies:
#
# **Example 1:**
#
# [Your example]
#
# **Example 2:**
#
# [Your example]

# %% [markdown]
# ### Integration Example (2 points)
# Write code that filters grades AND calculates the mean of passed students:

# %%
# Integration: Filter + Statistics
student_grades = [85, 42, 73, 95, 66, 88, 91, 54, 78, 82]

# Your code here: Filter passing grades AND calculate mean

# %% [markdown]
# ---
# # Section 3: Technical Depth - Multi-Approach Code Analysis (35 Points)
#
# *Bloom Levels: Apply, Analyze, Evaluate*

# %% [markdown]
# ## Task 3.1 - Alternative Solutions with Pedagogical Classification (15 Points)
#
# Implement FOUR different approaches to solve the grade filtering problem:

# %%
# Test data (use this for all solutions)
student_grades = [85, 42, 73, 95, 66, 88, 91, 54, 78, 82]
PASSING_THRESHOLD = 70

# %%
# LEVEL 1: Basic Logic - For Loop (3 points)
# Suitable for: Week 8 (after loops are introduced)

def filter_basic(grades, threshold):
    """
    Filter grades using a traditional for loop with if statement.
    
    Args:
        grades: List of numeric grades
        threshold: Minimum passing grade
    Returns:
        List of grades >= threshold
    """
    # Your implementation here
    pass

# Test
print("Level 1 Result:", filter_basic(student_grades, PASSING_THRESHOLD))

# %%
# LEVEL 2: Pythonic - List Comprehension (4 points)
# Suitable for: Week 9-10 (after list comprehensions are introduced)

def filter_comprehension(grades, threshold):
    """
    Filter grades using list comprehension.
    
    Args:
        grades: List of numeric grades
        threshold: Minimum passing grade
    Returns:
        List of grades >= threshold
    """
    # Your implementation here
    pass

# Test
print("Level 2 Result:", filter_comprehension(student_grades, PASSING_THRESHOLD))

# %%
# LEVEL 3: Functional - filter() with lambda (4 points)
# Suitable for: Week 11+ (advanced functional concepts)

def filter_functional(grades, threshold):
    """
    Filter grades using filter() and lambda.
    
    Args:
        grades: List of numeric grades
        threshold: Minimum passing grade
    Returns:
        List of grades >= threshold
    """
    # Your implementation here
    pass

# Test
print("Level 3 Result:", filter_functional(student_grades, PASSING_THRESHOLD))

# %%
# LEVEL 4: Robust Production - With Error Handling (4 points)
# Suitable for: Week 13 (error handling and debugging)

def filter_robust(grades, threshold=70):
    """
    Production-ready grade filter with error handling.
    
    Args:
        grades: List of numeric grades
        threshold: Minimum passing grade (default: 70)
    Returns:
        List of grades >= threshold
    Raises:
        TypeError: If grades is not a list or contains non-numeric values
        ValueError: If threshold is not between 0 and 100
    """
    # Your implementation here with:
    # - Empty list check
    # - Type validation
    # - Threshold validation
    pass

# Test normal case
print("Level 4 Result:", filter_robust(student_grades, PASSING_THRESHOLD))

# Test error cases (uncomment to test)
# print(filter_robust([]))
# print(filter_robust(["a", "b", "c"]))
# print(filter_robust(student_grades, 150))

# %% [markdown]
# ## Task 3.2 - Multi-Dimensional Comparative Analysis (12 Points)
#
# Complete the comparison table below. Rate each criterion as **Low / Medium / High** and provide pedagogical recommendations.

# %% [markdown]
# | Criterion | For Loop | List Comp | Filter | Pedagogical Note |
# |-----------|----------|-----------|--------|------------------|
# | **Readability** | ? | ? | ? | [Your recommendation] |
# | **Learning Curve** | ? | ? | ? | [Your recommendation] |
# | **Industry Relevance** | ? | ? | ? | [Your recommendation] |
# | **Debuggability** | ? | ? | ? | [Your recommendation] |
# | **Suggested Week** | ? | ? | ? | [Based on prerequisites] |

# %% [markdown]
# ### Justification for Ratings (Required)
#
# **Readability Justification:**
#
# [Explain your ratings]
#
# **Learning Curve Justification:**
#
# [Explain your ratings]
#
# **Industry Relevance Justification:**
#
# [Explain your ratings]
#
# **Debuggability Justification:**
#
# [Explain your ratings]

# %% [markdown]
# ## Task 3.3 - Real-World Extension (8 Points)
#
# Adapt your solutions to work with a dictionary data structure:

# %%
# Real-world scenario: Student records as dictionary
student_records = {"Ali": 85, "Ayse": 42, "Mehmet": 73, "Zeynep": 95, "Can": 66}

# Task: Filter students who passed (>=70) and return their names AND grades (4 points)
# Your implementation here:

# %% [markdown]
# ### Analysis Question (4 points)
#
# Which of your four approaches adapts most naturally to dictionaries? Why?
#
# **Your Answer:**
#
# [Write your analysis here]

# %% [markdown]
# ---
# # Section 4: Integrated Improvement Design (20 Points)
#
# *Bloom Levels: Evaluate, Create*

# %% [markdown]
# ## Task 4.1 - Spiral Learning Curriculum Design (10 Points)
#
# Design a "spiral learning" approach where loops are revisited at increasing depth:

# %% [markdown]
# ### Turn 1: Conceptual Introduction
#
# **Week:** [Specify week number]
#
# **Prerequisites:** [List prerequisites]
#
# **Learning Objectives:**
# - [Objective 1]
# - [Objective 2]
#
# **Sample Problem:** [Describe a real-world example without code]
#
# **Assessment Method:** [How would you assess understanding?]

# %% [markdown]
# ### Turn 2: Basic Application
#
# **Week:** [Specify week number]
#
# **Prerequisites:** [List prerequisites]
#
# **Learning Objectives:**
# - [Objective 1]
# - [Objective 2]
#
# **Sample Problem:** [Describe a coding exercise]
#
# **Assessment Method:** [How would you assess understanding?]

# %% [markdown]
# ### Turn 3: Optimization
#
# **Week:** [Specify week number]
#
# **Prerequisites:** [List prerequisites]
#
# **Learning Objectives:**
# - [Objective 1]
# - [Objective 2]
#
# **Sample Problem:** [Describe a refactoring exercise]
#
# **Assessment Method:** [How would you assess understanding?]

# %% [markdown]
# ### Turn 4: Advanced Application
#
# **Week:** [Specify week number]
#
# **Prerequisites:** [List prerequisites]
#
# **Learning Objectives:**
# - [Objective 1]
# - [Objective 2]
#
# **Sample Problem:** [Describe a file processing exercise]
#
# **Assessment Method:** [How would you assess understanding?]

# %% [markdown]
# ## Task 4.2 - Multi-Dimensional Assessment Rubric (10 Points)
#
# Design an assessment system that evaluates more than just code correctness. For each criterion, define what scores of 1, 3, and 5 look like:

# %% [markdown]
# ### Criterion 1: Algorithm Quality (0-5 points)
# **What it measures:** Problem decomposition accuracy
#
# | Score | Description |
# |-------|-------------|
# | 1 | [Describe minimal performance] |
# | 3 | [Describe acceptable performance] |
# | 5 | [Describe excellent performance] |
#
# **Why this matters for professional development:**
#
# [Your explanation]

# %% [markdown]
# ### Criterion 2: Code Readability (0-5 points)
# **What it measures:** Variable names, comments, structure
#
# | Score | Description |
# |-------|-------------|
# | 1 | [Describe minimal performance] |
# | 3 | [Describe acceptable performance] |
# | 5 | [Describe excellent performance] |
#
# **Why this matters for professional development:**
#
# [Your explanation]

# %% [markdown]
# ### Criterion 3: Efficiency (0-5 points)
# **What it measures:** Appropriate Python constructs used
#
# | Score | Description |
# |-------|-------------|
# | 1 | [Describe minimal performance] |
# | 3 | [Describe acceptable performance] |
# | 5 | [Describe excellent performance] |
#
# **Why this matters for professional development:**
#
# [Your explanation]

# %% [markdown]
# ### Criterion 4: Robustness (0-5 points)
# **What it measures:** Error handling, edge cases
#
# | Score | Description |
# |-------|-------------|
# | 1 | [Describe minimal performance] |
# | 3 | [Describe acceptable performance] |
# | 5 | [Describe excellent performance] |
#
# **Why this matters for professional development:**
#
# [Your explanation]

# %% [markdown]
# ### Criterion 5: Creativity (0-5 points)
# **What it measures:** Alternative solutions offered
#
# | Score | Description |
# |-------|-------------|
# | 1 | [Describe minimal performance] |
# | 3 | [Describe acceptable performance] |
# | 5 | [Describe excellent performance] |
#
# **Why this matters for professional development:**
#
# [Your explanation]

# %% [markdown]
# ### Criterion 6: Self-Evaluation (0-5 points)
# **What it measures:** Metacognitive reflection quality
#
# | Score | Description |
# |-------|-------------|
# | 1 | [Describe minimal performance] |
# | 3 | [Describe acceptable performance] |
# | 5 | [Describe excellent performance] |
#
# **Why this matters for professional development:**
#
# [Your explanation]

# %% [markdown]
# ---
# ### 📊 How You Will Be Evaluated
#
# | What Matters | Points Approach |
# |--------------|-----------------|
# | **Thinking process**, not just correct answers | Show your reasoning |
# | **Personal experience** = base points | Add **research/evidence** = bonus points |
# | **Code runs** = base points | Code is **readable & commented** = bonus points |
# | **Critique without solution** = half credit | Always propose alternatives |
#
# ### ⚠️ Common Mistakes to Avoid
#
# 1. ❌ Copying AI-generated code → **0 points for that task**
# 2. ❌ Writing "this topic is hard" → That's not analysis. Explain **WHY** it's hard
# 3. ❌ Four solutions with identical logic → Counts as **one solution only**
# 4. ❌ Empty AI Usage Log with sophisticated answers → **Triggers integrity review**
# 5. ❌ Generic pedagogical language without DSA105 specifics → Shows lack of genuine reflection
#
# ---

# %% [markdown]
# ---
# # Appendix A: AI Usage Log (Required)
#
# Document **every** interaction with AI tools during this project:

# %% [markdown]
# | Date/Time | Tool Used | Your Prompt (Summary) | What You Learned | How You Changed Your Work |
# |-----------|-----------|----------------------|------------------|---------------------------|
# | YYYY-MM-DD | e.g., ChatGPT | e.g., "matplotlib bar chart colors" | e.g., Use color= parameter | e.g., Added colors to chart |
# | | | | | |
# | | | | | |
# | | | | | |
#
# **Declaration:** I confirm that all AI usage has been documented above and that no AI was used to generate final solutions, analysis, or personal reflections.
#
# **Student Signature:** [Type your name as signature]

# %% [markdown]
# ---
# ## End of Project
#
# **Submission Checklist:**
# - [ ] All sections completed
# - [ ] All code cells executed without errors
# - [ ] AI Usage Log completed
# - [ ] File renamed to: `DSA105_Final_StudentID_Surname.ipynb`
# - [ ] File compressed as .zip
# - [ ] Uploaded to UBS before deadline
